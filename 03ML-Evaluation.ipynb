# %% [markdown]
# #### Why do we evaluate models?
#
# A model is “good” only if it performs well on unseen data.
#
# ![image.png](attachment:30e6ef90-8fa5-46b7-b9c7-329d72df33cf.png)
#
# ##### Confusion Matrix
#
# ![image.png](attachment:e137cfd0-ce00-4e9c-9200-83b99d7e5fb9.png)
#
# #### Precision vs Recall
#
# ![image.png](attachment:4b7887e2-4dbe-4378-bd07-5ca0b5be4983.png)
#
# ## What is F1 score?
#
# ![image.png](attachment:d2c9a509-7395-44b6-a396-611414d59e79.png)
#
# #### ROC Curve & AUC (ranking ability)
#
# ![image.png](attachment:536afc98-94c0-4ff0-9b92-89fa9a25f08f.png)
